# %%
csv_path = 'Dataset/Instacart_original.csv'
df = pd.read_csv(csv_path, index_col=0)
df
# Out:
#         order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0              2        1973                  1          5                  9
# 1              2        1050                  2          5                  9
# 2              2         560                  4          5                  9
# 3              3        1045                  1          5                 17
# 4              3        1476                  2          5                 17
# ...          ...         ...                ...        ...                ...
# 323700    105628         431                  5          4                 16
# 323701    105629        1525                  1          0                 13
# 323702    105629         419                  2          0                 13
# 323703    105629         185                  3          0                 13
# 323704    105629        1113                  5          0                 13
#
#         length                                     product_name  aisle_id  \
# 0            3                               Organic Egg Whites        78
# 1            3                                          Carrots        75
# 2            3                                    Garlic Powder        94
# 3            5  Unsweetened Chocolate Almond Breeze Almond Milk        83
# 4            5                           Unsweetened Almondmilk        83
# ...        ...                                              ...       ...
# 323700       5                            Light Semisoft Cheese        20
# 323701       4                Boneless Skinless Chicken Breasts        45
# 323702       4                       Organic White Basmati Rice        58
# 323703       4                   Organic Short Grain Brown Rice        58
# 323704       4                     Original Enriched Rice Drink        83
#
#         department_id                    aisle       department
# 0                  16                     eggs       dairy eggs
# 1                   4         fresh vegetables          produce
# 2                  13        spices seasonings           pantry
# 3                  16          soy lactosefree       dairy eggs
# 4                  16          soy lactosefree       dairy eggs
# ...               ...                      ...              ...
# 323700             16          packaged cheese       dairy eggs
# 323701             12         packaged poultry     meat seafood
# 323702              9  grains rice dried goods  dry goods pasta
# 323703              9  grains rice dried goods  dry goods pasta
# 323704             16          soy lactosefree       dairy eggs
#
# [323705 rows x 11 columns]

# %%
import pandas as pd

# %%
df1 = df[(df['order_dow'] == 5) & (df['order_hour_of_day'] == 9)]
df1
# Out:
#         order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0              2        1973                  1          5                  9
# 1              2        1050                  2          5                  9
# 2              2         560                  4          5                  9
# 540          174        1596                  1          5                  9
# 541          174        1825                  2          5                  9
# ...          ...         ...                ...        ...                ...
# 322425    105211          20                  4          5                  9
# 322426    105211        2385                  5          5                  9
# 322510    105236        1507                  1          5                  9
# 322511    105236        1671                  2          5                  9
# 322512    105236        1770                  3          5                  9
#
#         length               product_name  aisle_id  department_id  \
# 0            3         Organic Egg Whites        78             16
# 1            3                    Carrots        75              4
# 2            3              Garlic Powder        94             13
# 540          4          Fresh Cauliflower        75              4
# 541          4      Island Vanilla Cereal       108             14
# ...        ...                        ...       ...            ...
# 322425       5                 Cantaloupe        22              4
# 322426       5                Gold Potato        75              4
# 322510       3  Seedless Small Watermelon        22              4
# 322511       3         Organic Fuji Apple        22              4
# 322512       3                  Red Plums        22              4
#
#                     aisle  department
# 0                    eggs  dairy eggs
# 1        fresh vegetables     produce
# 2       spices seasonings      pantry
# 540      fresh vegetables     produce
# 541                cereal   breakfast
# ...                   ...         ...
# 322425       fresh fruits     produce
# 322426   fresh vegetables     produce
# 322510       fresh fruits     produce
# 322511       fresh fruits     produce
# 322512       fresh fruits     produce
#
# [3304 rows x 11 columns]

# %%
listt = [
  "Freshly Shaved Parmesan Cheese",
  "Fennel",
  "Elbow Macaroni Pasta",
  "Multigrain Sandwich Bread",
  "Ancient Grain Granola Cranberry Pecan",
  "Honey Bunches of Oats Honey Roasted Cereal",
  "Mandarin Oranges",
  "Apple Pie Fruit & Nut Food Bar",
  "Organic Stage 2 Peaches & Bananas Baby Food",
  "Rich Taste Extra Virgin Olive Oil"
]
# for i in range(len(listt)):
test = df1[df1['product_name'] == "Fennel"]
print(test)
# Out:
#         order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 195519     64051        2451                  2          5                  9
#
#         length product_name  aisle_id  department_id             aisle  \
# 195519       5       Fennel        75              4  fresh vegetables
#
#        department
# 195519    produce
